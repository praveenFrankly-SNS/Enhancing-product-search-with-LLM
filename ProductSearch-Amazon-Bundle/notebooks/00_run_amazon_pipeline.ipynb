# %%
# Databricks notebook source
# %md
# 🚀 Master Amazon Pipeline Orchestrator
**Purpose**: Run the complete Amazon Product Search ingestion & vector search indexing pipeline interactively.

> **Note**: Use this master notebook directly in Databricks Workspace UI if automated Job runs are restricted on Community / Trial accounts.

# %% [markdown]
# ### Step 1: Validate Environment

# %%
# %run ./00_validate_environment

# %% [markdown]
# ### Step 2: Setup Unity Catalog Delta Table Schema

# %%
# %run ./01_setup_platform

# %% [markdown]
# ### Step 3: Ingest Amazon CSV & Build Embeddings Document

# %%
# %run ./02_ingest_amazon_csv

# %% [markdown]
# ### Step 4: Create & Sync Delta Vector Search Index

# %%
# %run ./03_vector_search_index

# %% [markdown]
# ### Step 5: Test Vector Search Query

# %%
# %run ./04_test_amazon_search
